# %%
pwd
# Out:
# '/Users/aaron/space/show_the_data'

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import numpy as np

def right_angle(ax, corner, d1, d2, size=0.12, **kwargs):
    c = np.asarray(corner, dtype=float)
    u = np.asarray(d1, dtype=float); u /= np.hypot(*u)
    v = np.asarray(d2, dtype=float); v /= np.hypot(*v)
    pts = np.array([c + size*u, c + size*(u + v), c + size*v])
    ax.plot(pts[:, 0], pts[:, 1], color='black', lw=1, zorder=2, **kwargs)

fig, ax = plt.subplots()

p1 = (1, 1)
p2 = (4, 2)
p3 = (3, 3)

# ax.scatter(*p1, zorder=3, color='black')
ax.scatter(*p2, zorder=3, color='black')
ax.scatter(*p3, zorder=3, color='black')

# ax.annotate('', xy=(10, 10), xytext=(-10, -10),
#             arrowprops=dict(arrowstyle='-', color='black', lw=2),
#             zorder=2)

ax.axline((0, 0), slope=1, color='black', lw=2, zorder=2)

ax.text(2, 2, 'equal values', rotation=45, rotation_mode='anchor',
        ha='center', va='bottom', fontsize=12)
ax.text(4, 1.8, '(4, 2)', ha='center', va='top', fontsize=12)

ax.text(4, 2.5, 'take from\nfirst, add\nto second',
        ha='center', va='bottom', fontsize=12)

ax.text(2.7, 3.1, '(3, 3)', ha='center', va='bottom', fontsize=12)


ax.plot([4, 3], [2, 3], color='black', lw=1.5, linestyle=':', zorder=2)
ax.annotate('', xy=(3.04, 2.96), xytext=(4, 2), zorder=2,
            arrowprops=dict(arrowstyle='-|>', color='black', lw=0,
                            shrinkA=0, shrinkB=0, mutation_scale=16))
# ax.annotate('', xy=(3, 3), xytext=(4, 2), zorder=2,
#             arrowprops=dict(arrowstyle='-|>', color='black', lw=1.5,
#                             linestyle=':', shrinkA=0, shrinkB=0,
#                             mutation_scale=16))

# ax.plot([3, 4], [3, 2], color='black', lw=2, zorder=2)
# right_angle(ax, (3, 3), (-1, -1), (1, -1))    # between y=x and the segment
# ax.text(3.44, 2.44, r'$e$', ha='right', va='top', fontsize=12)

# ax.plot([3, 4], [3, 3], color='black', lw=1, linestyle='--', zorder=1)  # horizontal
# ax.plot([4, 4], [3, 2], color='black', lw=1, linestyle='--', zorder=1)  # vertical
# ax.text(3.6, 3.05, r'$e_1$', ha='center', va='bottom', fontsize=12)
# ax.text(4.05, 2.5, r'$e_2$', ha='left', va='center', fontsize=12)

# right_angle(ax, (4, 3), (-1, 0), (0, -1))   # between the two dashed legs

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.set_xlim(-0.5, 4.5)
ax.set_ylim(-0.5, 3.5)

ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

def hide_zero(x, pos):
    return '' if x == 0 else f'{int(x)}'

ax.xaxis.set_major_formatter(ticker.FuncFormatter(hide_zero))
ax.yaxis.set_major_formatter(ticker.FuncFormatter(hide_zero))

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.tick_params(axis='x', pad=10)
ax.tick_params(axis='y', pad=10)

plt.xlabel("First item")
plt.ylabel("Second item")

ax.set_aspect('equal', adjustable='box')

fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)

fig.savefig('plot_a.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import numpy as np

def right_angle(ax, corner, d1, d2, size=0.12, **kwargs):
    c = np.asarray(corner, dtype=float)
    u = np.asarray(d1, dtype=float); u /= np.hypot(*u)
    v = np.asarray(d2, dtype=float); v /= np.hypot(*v)
    pts = np.array([c + size*u, c + size*(u + v), c + size*v])
    ax.plot(pts[:, 0], pts[:, 1], color='black', lw=1, zorder=2, **kwargs)

fig, ax = plt.subplots()

p1 = (1, 1)
p2 = (4, 2)
p3 = (3, 3)

ax.scatter(*p1, zorder=3, color='black')
ax.scatter(*p2, zorder=3, color='black')
ax.scatter(*p3, zorder=3, color='black')

# ax.annotate('', xy=(10, 10), xytext=(-10, -10),
#             arrowprops=dict(arrowstyle='-', color='black', lw=2),
#             zorder=2)

ax.axline((0, 0), slope=1, color='black', lw=2, zorder=2)

# ax.text(2, 2, 'equal', rotation=45, rotation_mode='anchor',
#         ha='center', va='bottom', fontsize=12)
ax.text(4, 1.8, 'y=(4, 2)', ha='center', va='top', fontsize=12)

ax.text(2.7, 3.1, '(3, 3)', ha='center', va='bottom', fontsize=12)
ax.text(0.7, 1.1, 'x=(1, 1)', ha='center', va='bottom', fontsize=12)


ax.plot([3, 4], [3, 2], color='black', lw=2, zorder=2)
right_angle(ax, (3, 3), (-1, -1), (1, -1))    # between y=x and the segment
# ax.text(3.44, 2.44, r'$e$', ha='right', va='top', fontsize=12)

# ax.plot([3, 4], [3, 3], color='black', lw=1, linestyle='--', zorder=1)  # horizontal
# ax.plot([4, 4], [3, 2], color='black', lw=1, linestyle='--', zorder=1)  # vertical
# ax.text(3.6, 3.05, r'$e_1$', ha='center', va='bottom', fontsize=12)
# ax.text(4.05, 2.5, r'$e_2$', ha='left', va='center', fontsize=12)

# right_angle(ax, (4, 3), (-1, 0), (0, -1))   # between the two dashed legs

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.set_xlim(-0.5, 4.5)
ax.set_ylim(-0.5, 3.5)

ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

def hide_zero(x, pos):
    return '' if x == 0 else f'{int(x)}'

ax.xaxis.set_major_formatter(ticker.FuncFormatter(hide_zero))
ax.yaxis.set_major_formatter(ticker.FuncFormatter(hide_zero))

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.tick_params(axis='x', pad=10)
ax.tick_params(axis='y', pad=10)

plt.xlabel("First item")
plt.ylabel("Second item")

ax.set_aspect('equal', adjustable='box')

fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)

fig.savefig('plot_b.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import numpy as np

def right_angle(ax, corner, d1, d2, size=0.12, **kwargs):
    c = np.asarray(corner, dtype=float)
    u = np.asarray(d1, dtype=float); u /= np.hypot(*u)
    v = np.asarray(d2, dtype=float); v /= np.hypot(*v)
    pts = np.array([c + size*u, c + size*(u + v), c + size*v])
    ax.plot(pts[:, 0], pts[:, 1], color='black', lw=1, zorder=2, **kwargs)

fig, ax = plt.subplots()

p1 = (1, 1)
p2 = (4, 2)
p3 = (3, 3)

# ax.scatter(*p1, zorder=3, color='black')
ax.scatter(*p2, zorder=3, color='black')
ax.scatter(*p3, zorder=3, color='black')

# ax.annotate('', xy=(10, 10), xytext=(-10, -10),
#             arrowprops=dict(arrowstyle='-', color='black', lw=2),
#             zorder=2)

ax.axline((0, 0), slope=1, color='black', lw=2, zorder=2)

# ax.text(2, 2, 'equal', rotation=45, rotation_mode='anchor',
#         ha='center', va='bottom', fontsize=12)
# ax.text(4, 1.8, '(4, 2)', ha='center', va='top', fontsize=12)

ax.plot([3, 4], [3, 2], color='black', lw=2, zorder=2)
right_angle(ax, (3, 3), (-1, -1), (1, -1))    # between y=x and the segment
ax.text(3.44, 2.44, r'$e$', ha='right', va='top', fontsize=12)

ax.plot([3, 4], [3, 3], color='black', lw=1, linestyle='--', zorder=1)  # horizontal
ax.plot([4, 4], [3, 2], color='black', lw=1, linestyle='--', zorder=1)  # vertical
ax.text(3.6, 3.05, r'$e_1$', ha='center', va='bottom', fontsize=12)
ax.text(4.05, 2.5, r'$e_2$', ha='left', va='center', fontsize=12)

right_angle(ax, (4, 3), (-1, 0), (0, -1))   # between the two dashed legs

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.set_xlim(-0.5, 4.5)
ax.set_ylim(-0.5, 3.5)

ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

def hide_zero(x, pos):
    return '' if x == 0 else f'{int(x)}'

ax.xaxis.set_major_formatter(ticker.FuncFormatter(hide_zero))
ax.yaxis.set_major_formatter(ticker.FuncFormatter(hide_zero))

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.tick_params(axis='x', pad=10)
ax.tick_params(axis='y', pad=10)

plt.xlabel("First item")
plt.ylabel("Second item")

ax.set_aspect('equal', adjustable='box')

fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)

fig.savefig('plot_c.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import numpy as np

def right_angle(ax, corner, d1, d2, size=0.12, **kwargs):
    c = np.asarray(corner, dtype=float)
    u = np.asarray(d1, dtype=float); u /= np.hypot(*u)
    v = np.asarray(d2, dtype=float); v /= np.hypot(*v)
    pts = np.array([c + size*u, c + size*(u + v), c + size*v])
    ax.plot(pts[:, 0], pts[:, 1], color='black', lw=1, zorder=2, **kwargs)

fig, ax = plt.subplots()

p1 = (1, 4)
p2 = (1, 2)
p3 = (1, 3)

ax.scatter(*p1, zorder=3, color='black')
ax.scatter(*p2, zorder=3, color='black')
ax.scatter(*p3, zorder=3, color='black')

# ax.annotate('', xy=(10, 10), xytext=(-10, -10),
#             arrowprops=dict(arrowstyle='-', color='black', lw=2),
#             zorder=2)

ax.axline((0, 0), slope=3, color='black', lw=2, zorder=2)

# ax.text(2, 2, 'equal', rotation=45, rotation_mode='anchor',
#         ha='center', va='bottom', fontsize=12)
# ax.text(4, 1.8, '(4, 2)', ha='center', va='top', fontsize=12)

# ax.plot([3, 4], [3, 2], color='black', lw=2, zorder=2)
# right_angle(ax, (3, 3), (-1, -1), (1, -1))    # between y=x and the segment
# ax.text(3.44, 2.44, r'$e$', ha='right', va='top', fontsize=12)

ax.plot([1, 1], [2, 4], color='black', lw=1, linestyle='--', zorder=1)  # horizontal
# ax.plot([4, 4], [3, 2], color='black', lw=1, linestyle='--', zorder=1)  # vertical
ax.text(0.75, 3.5, r'$e_1$', ha='center', va='center', fontsize=12)
ax.text(1.3, 2.5, r'$e_2$', ha='center', va='center', fontsize=12)

ax.text(0.5, 1.5, r'$y=3x$', rotation=71.57, rotation_mode='anchor',
        ha='center', va='bottom', fontsize=12)


# right_angle(ax, (4, 3), (-1, 0), (0, -1))   # between the two dashed legs

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.set_xlim(-0.5, 2.5)
ax.set_ylim(-0.5, 4.5)

ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

def hide_zero(x, pos):
    return '' if x == 0 else f'{int(x)}'

ax.xaxis.set_major_formatter(ticker.FuncFormatter(hide_zero))
ax.yaxis.set_major_formatter(ticker.FuncFormatter(hide_zero))

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.tick_params(axis='x', pad=10)
ax.tick_params(axis='y', pad=10)

plt.xlabel("$x$")
plt.ylabel("$y$")

ax.set_aspect('equal', adjustable='box')

fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)

fig.savefig('plot_d.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import numpy as np

def right_angle(ax, corner, d1, d2, size=0.12, **kwargs):
    c = np.asarray(corner, dtype=float)
    u = np.asarray(d1, dtype=float); u /= np.hypot(*u)
    v = np.asarray(d2, dtype=float); v /= np.hypot(*v)
    pts = np.array([c + size*u, c + size*(u + v), c + size*v])
    ax.plot(pts[:, 0], pts[:, 1], color='black', lw=1, zorder=2, **kwargs)

fig, ax = plt.subplots()

p1 = (1, 2)
p2 = (3, 1)
p3 = (1, 3)

ax.scatter(*p1, zorder=3, color='black')
ax.scatter(*p2, zorder=3, color='black')
# ax.scatter(*p3, zorder=3, color='black')

ax.text(1, 1.8, '(1, 2)', ha='center', va='top', fontsize=12)
ax.text(3, 0.8, '(3, 1)', ha='center', va='top', fontsize=12)



# ax.annotate('', xy=(10, 10), xytext=(-10, -10),
#             arrowprops=dict(arrowstyle='-', color='black', lw=2),
#             zorder=2)

# ax.axline((0, 0), slope=3, color='black', lw=2, zorder=2)

# ax.text(2, 2, 'equal', rotation=45, rotation_mode='anchor',
#         ha='center', va='bottom', fontsize=12)
# ax.text(4, 1.8, '(4, 2)', ha='center', va='top', fontsize=12)

# ax.plot([3, 4], [3, 2], color='black', lw=2, zorder=2)
# right_angle(ax, (3, 3), (-1, -1), (1, -1))    # between y=x and the segment
# ax.text(3.44, 2.44, r'$e$', ha='right', va='top', fontsize=12)

# ax.plot([1, 1], [2, 4], color='black', lw=1, linestyle='--', zorder=1)  # horizontal
# ax.plot([4, 4], [3, 2], color='black', lw=1, linestyle='--', zorder=1)  # vertical
# ax.text(0.75, 3.5, r'$e_1$', ha='center', va='center', fontsize=12)
# ax.text(1.3, 2.5, r'$e_2$', ha='center', va='center', fontsize=12)

# ax.text(0.5, 1.5, r'$y=3x$', rotation=71.57, rotation_mode='anchor',
        # ha='center', va='bottom', fontsize=12)


# right_angle(ax, (4, 3), (-1, 0), (0, -1))   # between the two dashed legs

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.set_xlim(-0.5, 3.5)
ax.set_ylim(-0.5, 2.5)

ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

def hide_zero(x, pos):
    return '' if x == 0 else f'{int(x)}'

ax.xaxis.set_major_formatter(ticker.FuncFormatter(hide_zero))
ax.yaxis.set_major_formatter(ticker.FuncFormatter(hide_zero))

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.tick_params(axis='x', pad=10)
ax.tick_params(axis='y', pad=10)

plt.xlabel("$x$")
plt.ylabel("$y$")

ax.set_aspect('equal', adjustable='box')

fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)

fig.savefig('plot_e.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import numpy as np

def right_angle(ax, corner, d1, d2, size=0.12, **kwargs):
    c = np.asarray(corner, dtype=float)
    u = np.asarray(d1, dtype=float); u /= np.hypot(*u)
    v = np.asarray(d2, dtype=float); v /= np.hypot(*v)
    pts = np.array([c + size*u, c + size*(u + v), c + size*v])
    ax.plot(pts[:, 0], pts[:, 1], color='black', lw=1, zorder=2, **kwargs)

fig, ax = plt.subplots()

p1 = (1, 3)
p2 = (2, 1)
p3 = (0.5, 1.5)

ax.scatter(*p1, zorder=3, color='black')
ax.scatter(*p2, zorder=3, color='black')
ax.scatter(*p3, zorder=3, color='black')

# ax.annotate('', xy=(10, 10), xytext=(-10, -10),
#             arrowprops=dict(arrowstyle='-', color='black', lw=2),
#             zorder=2)

ax.axline((0, 0), slope=3, color='black', lw=2, zorder=2)

# ax.text(2, 2, 'equal', rotation=45, rotation_mode='anchor',
#         ha='center', va='bottom', fontsize=12)
ax.text(2.2, 1, 'y=(2, 1)', ha='left', va='center', fontsize=12)

ax.text(0.7, 1.6, '(0.5, 1.5)', ha='left', va='center', fontsize=12)
ax.text(1.2, 3, 'x=(1, 3)', ha='left', va='center', fontsize=12)


ax.plot([2, 0.5], [1, 1.5], color='black', lw=2, zorder=2)
# right_angle(ax, (0.5, 1.5), (-1, -1), (1, -1))    # between y=x and the segment
right_angle(ax, (0.5, 1.5), (-1, -3), (3, -1), size=0.15)
# ax.text(3.44, 2.44, r'$e$', ha='right', va='top', fontsize=12)

# ax.plot([3, 4], [3, 3], color='black', lw=1, linestyle='--', zorder=1)  # horizontal
# ax.plot([4, 4], [3, 2], color='black', lw=1, linestyle='--', zorder=1)  # vertical
# ax.text(3.6, 3.05, r'$e_1$', ha='center', va='bottom', fontsize=12)
# ax.text(4.05, 2.5, r'$e_2$', ha='left', va='center', fontsize=12)

# right_angle(ax, (4, 3), (-1, 0), (0, -1))   # between the two dashed legs

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.set_xlim(-0.5, 3.5)
ax.set_ylim(-0.5, 3.5)

ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

def hide_zero(x, pos):
    return '' if x == 0 else f'{int(x)}'

ax.xaxis.set_major_formatter(ticker.FuncFormatter(hide_zero))
ax.yaxis.set_major_formatter(ticker.FuncFormatter(hide_zero))

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.tick_params(axis='x', pad=10)
ax.tick_params(axis='y', pad=10)

plt.xlabel("First item")
plt.ylabel("Second item")

ax.set_aspect('equal', adjustable='box')

fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)

fig.savefig('plot_f.png', transparent=True, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import numpy as np

def right_angle(ax, corner, d1, d2, size=0.12, **kwargs):
    c = np.asarray(corner, dtype=float)
    u = np.asarray(d1, dtype=float); u /= np.hypot(*u)
    v = np.asarray(d2, dtype=float); v /= np.hypot(*v)
    pts = np.array([c + size*u, c + size*(u + v), c + size*v])
    ax.plot(pts[:, 0], pts[:, 1], color='black', lw=1, zorder=2, **kwargs)

fig, ax = plt.subplots()

p1 = (1, 2)
p2 = (3, 1)
p3 = (1, 3)

ax.scatter(*p1, zorder=3, color='black')
ax.scatter(*p2, zorder=3, color='black')
# ax.scatter(*p3, zorder=3, color='black')

# ax.text(1, 1.8, '(1, 2)', ha='center', va='top', fontsize=12)
# ax.text(3, 0.8, '(3, 1)', ha='center', va='top', fontsize=12)



# ax.annotate('', xy=(10, 10), xytext=(-10, -10),
#             arrowprops=dict(arrowstyle='-', color='black', lw=2),
#             zorder=2)

ax.axline((0, 0), slope=1/2, color='black', lw=2, zorder=2)

# ax.text(2, 2, 'equal', rotation=45, rotation_mode='anchor',
#         ha='center', va='bottom', fontsize=12)
# ax.text(4, 1.8, '(4, 2)', ha='center', va='top', fontsize=12)

# ax.plot([3, 4], [3, 2], color='black', lw=2, zorder=2)
# right_angle(ax, (3, 3), (-1, -1), (1, -1))    # between y=x and the segment
# ax.text(3.44, 2.44, r'$e$', ha='right', va='top', fontsize=12)

ax.plot([1, 1], [2, 0.5], color='black', lw=1, linestyle='--', zorder=1)
ax.plot([3, 3], [1, 1.5], color='black', lw=1, linestyle='--', zorder=1)
ax.text(1.1, 1.25, r'$e_1$', ha='left', va='center', fontsize=12)
ax.text(3.1, 1.25, r'$e_2$', ha='left', va='center', fontsize=12)

ax.text(2, 1, r'$y=0.5x$', rotation=26.57, rotation_mode='anchor',
        ha='center', va='bottom', fontsize=12)


# right_angle(ax, (4, 3), (-1, 0), (0, -1))   # between the two dashed legs

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.set_xlim(-0.5, 3.5)
ax.set_ylim(-0.5, 2.5)

ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

def hide_zero(x, pos):
    return '' if x == 0 else f'{int(x)}'

ax.xaxis.set_major_formatter(ticker.FuncFormatter(hide_zero))
ax.yaxis.set_major_formatter(ticker.FuncFormatter(hide_zero))

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.tick_params(axis='x', pad=10)
ax.tick_params(axis='y', pad=10)

plt.xlabel("$x$")
plt.ylabel("$y$")

ax.set_aspect('equal', adjustable='box')

fig.patch.set_alpha(0.0)
ax.patch.set_alpha(0.0)

fig.savefig('plot_g.png', transparent=True, bbox_inches='tight')
plt.show()
